# %%
import geopandas as gpd
import osmnx as ox
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
nearWestSide_roads = ox.graph_from_place('Near West Side, Chicago, Illinois, USA', network_type='drive', simplify = True)

# %%
ox.plot_graph(nearWestSide_roads)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
healthDept_node = ox.distance.nearest_nodes(nearWestSide_roads, 41.88261081439729, -87.66976101015001)
